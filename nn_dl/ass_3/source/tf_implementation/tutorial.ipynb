# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
logs_path = '/tmp/tensorflow_logs/example'

import tensorflow as tf
sess = tf.InteractiveSession()

x = tf.placeholder(tf.float32, shape=[None, 784])
y_ = tf.placeholder(tf.float32, shape=[None, 10])

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='VALID')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

W_conv1 = weight_variable([5, 5, 1, 6])
b_conv1 = bias_variable([6])
x_image = tf.reshape(x, [-1,28,28,1])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5, 5, 6, 16])
b_conv2 = bias_variable([16])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weight_variable([4 * 4 * 16, 120])
b_fc1 = bias_variable([120])

h_pool2_flat = tf.reshape(h_pool2, [-1, 4*4*16])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)


W_fc2 = weight_variable([120, 84])
b_fc2 = bias_variable([84])

h_fc2 = tf.nn.relu(tf.matmul(h_fc1, W_fc2) + b_fc2)

W_fc3 = weight_variable([84, 10])
b_fc3 = bias_variable([10])

y_conv = tf.matmul(h_fc2, W_fc3) + b_fc3

cross_entropy = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
train_step = tf.train.MomentumOptimizer(learning_rate=0.01,momentum=0.5).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

tf.summary.scalar("loss", cross_entropy)
tf.summary.scalar("accuracy", accuracy)
merged_summary_op = tf.summary.merge_all()

sess.run(tf.global_variables_initializer())
summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())
train_acc=[]
valid_acc=[]
for i in range(3000):
    batch = mnist.train.next_batch(50)
    if i%5 == 0:
        train_accuracy=accuracy.eval(feed_dict={x: batch[0], y_: batch[1]})
        train_acc.append(train_accuracy)
        #train_accuracy,summary = sess.run([accuracy,merged_summary_op],feed_dict={
        #    x:batch[0], y_: batch[1]})
        #summary_writer.add_summary(summary, i)
        validation_accuracy=accuracy.eval(feed_dict={x: mnist.validation.images[0:300], y_: mnist.validation.labels[0:300]})
        valid_acc.append(validation_accuracy)
        
    train_step.run(feed_dict={x: batch[0], y_: batch[1]})
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# step 0, training accuracy 0.04
# step 0, validation accuracy 0.0633333
# step 50, training accuracy 0.16
# step 50, validation accuracy 0.3
# step 100, training accuracy 0.52
# step 100, validation accuracy 0.58
# step 150, training accuracy 0.72
# step 150, validation accuracy 0.76
# step 200, training accuracy 0.96
# step 200, validation accuracy 0.82
# step 250, training accuracy 0.72
# step 250, validation accuracy 0.846667
# step 300, training accuracy 0.78
# step 300, validation accuracy 0.866667
# step 350, training accuracy 0.76
# step 350, validation accuracy 0.88
# step 400, training accuracy 0.94
# step 400, validation accuracy 0.893333
# step 450, training accuracy 0.9
# step 450, validation accuracy 0.906667
# step 500, training accuracy 0.84
# step 500, validation accuracy 0.883333
# step 550, training accuracy 0.9
# step 550, validation accuracy 0.896667
# step 600, training accuracy 0.98
# step 600, validation accuracy 0.92
# step 650, training accuracy 0.86
# step 650, validation accuracy 0.913333
# step 700, training accuracy 0.98
# step 700, validation accuracy 0.93
# step 750, training accuracy 0.84
# step 750, validation accuracy 0.92
# step 800, training accuracy 0.82
# step 800, validation accuracy 0.923333
# step 850, training accuracy 0.94
# step 850, validation accuracy 0.936667
# step 900, training accuracy 0.98
# step 900, validation accuracy 0.913333
# step 950, training accuracy 0.98
# step 950, validation accuracy 0.936667
# step 1000, training accuracy 0.96
# step 1000, validation accuracy 0.933333
# step 1050, training accuracy 0.94
# step 1050, validation accuracy 0.953333
# step 1100, training accuracy 0.92
# step 1100, validation accuracy 0.936667
# step 1150, training accuracy 0.94
# step 1150, validation accuracy 0.94
# step 1200, training accuracy 0.9
# step 1200, validation accuracy 0.94
# step 1250, training accuracy 0.94
# step 1250, validation accuracy 0.94
# step 1300, training accuracy 0.88
# step 1300, validation accuracy 0.943333
# step 1350, training accuracy 0.96
# step 1350, validation accuracy 0.953333
# step 1400, training accuracy 0.94
# step 1400, validation accuracy 0.946667
# step 1450, training accuracy 1
# step 1450, validation accuracy 0.953333
# step 1500, training accuracy 0.98
# step 1500, validation accuracy 0.95
# step 1550, training accuracy 0.98
# step 1550, validation accuracy 0.96
# step 1600, training accuracy 0.94
# step 1600, validation accuracy 0.926667
# step 1650, training accuracy 0.94
# step 1650, validation accuracy 0.936667
# step 1700, training accuracy 0.94
# step 1700, validation accuracy 0.956667
# step 1750, training accuracy 0.98
# step 1750, validation accuracy 0.966667
# step 1800, training accuracy 0.98
# step 1800, validation accuracy 0.966667
# step 1850, training accuracy 1
# step 1850, validation accuracy 0.96
# step 1900, training accuracy 0.98
# step 1900, validation accuracy 0.956667
# step 1950, training accuracy 0.94
# step 1950, validation accuracy 0.946667
# step 2000, training accuracy 0.98
# step 2000, validation accuracy 0.953333
# step 2050, training accuracy 0.94
# step 2050, validation accuracy 0.953333
# step 2100, training accuracy 0.98
# step 2100, validation accuracy 0.96
# step 2150, training accuracy 0.98
# step 2150, validation accuracy 0.963333
# step 2200, training accuracy 1
# step 2200, validation accuracy 0.966667
# step 2250, training accuracy 0.98
# step 2250, validation accuracy 0.96
# step 2300, training accuracy 0.94
# step 2300, validation accuracy 0.966667
# step 2350, training accuracy 0.96
# step 2350, validation accuracy 0.963333
# step 2400, training accuracy 0.98
# step 2400, validation accuracy 0.97
# step 2450, training accuracy 1
# step 2450, validation accuracy 0.96
# step 2500, training accuracy 0.98
# step 2500, validation accuracy 0.96
# step 2550, training accuracy 0.98
# step 2550, validation accuracy 0.963333
# step 2600, training accuracy 1
# step 2600, validation accuracy 0.963333
# step 2650, training accuracy 0.96
# step 2650, validation accuracy 0.966667
# step 2700, training accuracy 0.98
# step 2700, validation accuracy 0.963333
# step 2750, training accuracy 0.96
# step 2750, validation accuracy 0.97
# step 2800, training accuracy 0.96
# step 2800, validation accuracy 0.966667
# step 2850, training accuracy 0.96
# step 2850, validation accuracy 0.966667
# step 2900, training accuracy 0.94
# step 2900, validation accuracy 0.966667
# step 2950, training accuracy 0.98
# step 2950, validation accuracy 0.966667
